# %%
# %matplotlib notebook
from pymba import Vimba, VimbaException
import time
import matplotlib.pyplot as plt
import numpy as np
import csv
from datetime import datetime
from pathlib import Path

# %% [markdown]
# import all the features

# %%
dtype = None
with Vimba() as vimba:
        camera = vimba.camera('DEV_000F315C8C83')
        camera.open()
        for feature_name in camera.feature_names():
            feature = camera.feature(feature_name)

            try:
                value = feature.value
                range_ = feature.range
                dtype = type(value)

                # alternatively the feature value can be read as an object attribute
                # value = getattr(camera, feature_name)
                # or
                # value = camera.someFeatureName

            except VimbaException as e:
                value = e
                range_ = None

            print('\n\t'.join(
                str(x) for x in (
                    feature_name,
                    'value: {}'.format(value),
                    'range: {}'.format(range_),
                    'type:{}'.format(dtype))
                if x is not None))
            
        camera.close()
# Out:
# AcquisitionAbort
# 	value: Cannot get or set the value of a command feature type, call the command instead.
# 	range: None
# 	type:None
# AcquisitionFrameCount
# 	value: 1
# 	range: (1, 65535)
# 	type:<class 'int'>
# AcquisitionFrameRateAbs
# 	value: 309.98140111593307
# 	range: (0.0015129371986062677, 3067.4846625766872)
# 	type:<class 'float'>
# AcquisitionFrameRateLimit
# 	value: 1165.5011655011656
# 	range: (0.0015129371986062677, 3067.4846625766872)
# 	type:<class 'float'>
# AcquisitionMode
# 	value: SingleFrame
# 	range: ['Continuous', 'SingleFrame', 'MultiFrame', 'Recorder']
# 	type:<class 'str'>
# AcquisitionStart
# 	value: Cannot get or set the value of a command feature type, call the command instead.
# 	range: None
# 	type:<class 'str'>
# AcquisitionStop
# 	value: Cannot get or set the value of a command feature type, call the command instead.
# 	range: None
# 	type:<class 'str'>
# BandwidthControlMode
# 	value: StreamBytesPerSecond
# 	range: ['StreamBytesPerSecond', 'SCPD', 'Both']
# 	type:<class 'str'>
# BlackLevel
# 	value: 4.0
# 	range: (0.0, 255.75)
# 	type:<class 'float'>
# BlackLevelSelector
# 	value: All
# 	range: ['All']
# 	type:<class 'str'>
# ChunkModeActive
# 	value: False
# 	range: None
# 	type:<class 'bool'>
# DSPSubregionBottom
# 	value: 484
# 	range: (1, 484)
# 	type:<class 'int'>
# DSPSubregionLeft
# 	value: 0
# 	range: (0, 643)
# 	type:<class 'int'>
# DSPSubregionRight
# 	value: 644
# 	range: (1, 644)
# 	type:<class 'int'>
# DSPSubregionTop
# 	value: 0
# 	range: (0, 483)
# 	type:<class 'int'>
# DecimationHorizontal
# 	value: 1
# 	range: (1, 4)
# 	type:<class 'int'>
# DecimationVertical
# 	value: 1
# 	range: (1, 4)
# 	type:<class 'int'>
# DefectMaskEnable
# 	value: True
# 	range: None
# 	type:<class 'bool'>
# DeviceFirmwareVersion
# 	value: 00.01.54.18391
# 	range: None
# 	type:<class 'str'>
# DeviceID
# 	value: 50-0536936451
# 	range: None
# 	type:<class 'str'>
# DeviceModelName
# 	value: Mako G-030B
# 	range: None
# 	type:<class 'str'>
# DevicePartNumber
# 	value: 5044
# 	range: None
# 	type:<class 'str'>
# DeviceScanType
# 	value: Areascan
# 	range: ['Areascan']
# 	type:<class 'str'>
# DeviceTemperature
# 	value: 58.15599822998047
# 	range: (-1.7976931348623157e+308, 1.7976931348623157e+308)
# 	type:<class 'float'>
# DeviceTemperatureSelector
# 	value: Main
# 	range: ['Sensor', 'Main', 'Power']
# 	type:<class 'str'>
# DeviceUserID
# 	value:
# 	range: None
# 	type:<class 'str'>
# DeviceVendorName
# 	value: Allied Vision Technologies
# 	range: None
# 	type:<class 'str'>
# EventAcquisitionEnd
# 	value: 40001
# 	range: (-9223372036854775808, 9223372036854775807)
# 	type:<class 'int'>
# EventAcquisitionEndFrameID
# 	value: 0
# 	range: (0, 4294967295)
# 	type:<class 'int'>
# EventAcquisitionEndTimestamp
# 	value: 0
# 	range: (0, 9223372036854775807)
# 	type:<class 'int'>
# EventAcquisitionRecordTrigger
# 	value: 40004
# 	range: (-9223372036854775808, 9223372036854775807)
# 	type:<class 'int'>
# EventAcquisitionRecordTriggerFrameID
# 	value: 0
# 	range: (0, 4294967295)
# 	type:<class 'int'>
# EventAcquisitionRecordTriggerTimestamp
# 	value: 0
# 	range: (0, 9223372036854775807)
# 	type:<class 'int'>
# EventAcquisitionStart
# 	value: 40000
# 	range: (-9223372036854775808, 9223372036854775807)
# 	type:<class 'int'>
# EventAcquisitionStartFrameID
# 	value: 0
# 	range: (0, 4294967295)
# 	type:<class 'int'>
# EventAcquisitionStartTimestamp
# 	value: 0
# 	range: (0, 9223372036854775807)
# 	type:<class 'int'>
# EventError
# 	value: 65535
# 	range: (-9223372036854775808, 9223372036854775807)
# 	type:<class 'int'>
# EventErrorFrameID
# 	value: 0
# 	range: (0, 4294967295)
# 	type:<class 'int'>
# EventErrorTimestamp
# 	value: 0
# 	range: (0, 9223372036854775807)
# 	type:<class 'int'>
# EventExposureEnd
# 	value: 40003
# 	range: (-9223372036854775808, 9223372036854775807)
# 	type:<class 'int'>
# EventExposureEndFrameID
# 	value: 0
# 	range: (0, 4294967295)
# 	type:<class 'int'>
# EventExposureEndTimestamp
# 	value: 0
# 	range: (0, 9223372036854775807)
# 	type:<class 'int'>
# EventExposureStart
# 	value: 40019
# 	range: (-9223372036854775808, 9223372036854775807)
# 	type:<class 'int'>
# EventExposureStartFrameID
# 	value: 0
# 	range: (0, 4294967295)
# 	type:<class 'int'>
# EventExposureStartTimestamp
# 	value: 0
# 	range: (0, 9223372036854775807)
# 	type:<class 'int'>
# EventFrameTrigger
# 	value: 40002
# 	range: (-9223372036854775808, 9223372036854775807)
# 	type:<class 'int'>
# EventFrameTriggerFrameID
# 	value: 0
# 	range: (0, 4294967295)
# 	type:<class 'int'>
# EventFrameTriggerReady
# 	value: 40018
# 	range: (-9223372036854775808, 9223372036854775807)
# 	type:<class 'int'>
# EventFrameTriggerReadyFrameID
# 	value: 0
# 	range: (0, 4294967295)
# 	type:<class 'int'>
# EventFrameTriggerReadyTimestamp
# 	value: 0
# 	range: (0, 9223372036854775807)
# 	type:<class 'int'>
# EventFrameTriggerTimestamp
# 	value: 0
# 	range: (0, 9223372036854775807)
# 	type:<class 'int'>
# EventLine1FallingEdge
# 	value: 40011
# 	range: (-9223372036854775808, 9223372036854775807)
# 	type:<class 'int'>
# EventLine1FallingEdgeFrameID
# 	value: 0
# 	range: (0, 4294967295)
# 	type:<class 'int'>
# EventLine1FallingEdgeTimestamp
# 	value: 0
# 	range: (0, 9223372036854775807)
# 	type:<class 'int'>
# EventLine1RisingEdge
# 	value: 40010
# 	range: (-9223372036854775808, 9223372036854775807)
# 	type:<class 'int'>
# EventLine1RisingEdgeFrameID
# 	value: 0
# 	range: (0, 4294967295)
# 	type:<class 'int'>
# EventLine1RisingEdgeTimestamp
# 	value: 0
# 	range: (0, 9223372036854775807)
# 	type:<class 'int'>
# EventLine2FallingEdge
# 	value: 40013
# 	range: (-9223372036854775808, 9223372036854775807)
# 	type:<class 'int'>
# EventLine2RisingEdge
# 	value: 40012
# 	range: (-9223372036854775808, 9223372036854775807)
# 	type:<class 'int'>
# EventNotification
# 	value: Off
# 	range: ['Off', 'On']
# 	type:<class 'str'>
# EventOverflow
# 	value: 65534
# 	range: (-9223372036854775808, 9223372036854775807)
# 	type:<class 'int'>
# EventOverflowFrameID
# 	value: 0
# 	range: (0, 4294967295)
# 	type:<class 'int'>
# EventOverflowTimestamp
# 	value: 0
# 	range: (0, 9223372036854775807)
# 	type:<class 'int'>
# EventSelector
# 	value: ExposureStart
# 	range: ['AcquisitionStart', 'AcquisitionEnd', 'FrameTrigger', 'ExposureEnd', 'AcquisitionRecordTrigger', 'Line1RisingEdge', 'Line1FallingEdge', 'Line2RisingEdge', 'Line2FallingEdge', 'Line3RisingEdge', 'Line3FallingEdge', 'Line4RisingEdge', 'Line4FallingEdge', 'FrameTriggerReady', 'ExposureStart']
# 	type:<class 'str'>
# EventsEnable1
# 	value: 0
# 	range: (0, 4294967295)
# 	type:<class 'int'>
# ExposureAuto
# 	value: Off
# 	range: ['Off', 'Once', 'Continuous']
# 	type:<class 'str'>
# ExposureAutoAdjustTol
# 	value: 5
# 	range: (0, 50)
# 	type:<class 'int'>
# ExposureAutoAlg
# 	value: Mean
# 	range: ['Mean', 'FitRange']
# 	type:<class 'str'>
# ExposureAutoMax
# 	value: 500000
# 	range: (83, 2000000)
# 	type:<class 'int'>
# ExposureAutoMin
# 	value: 83
# 	range: (83, 2000000)
# 	type:<class 'int'>
# ExposureAutoOutliers
# 	value: 0
# 	range: (0, 1000)
# 	type:<class 'int'>
# ExposureAutoRate
# 	value: 100
# 	range: (1, 100)
# 	type:<class 'int'>
# ExposureAutoTarget
# 	value: 50
# 	range: (0, 100)
# 	type:<class 'int'>
# ExposureMode
# 	value: Timed
# 	range: ['Timed', 'TriggerWidth', 'PieceWiseLinearHDR', 'InterleavedHDR', 'BracketHDR']
# 	type:<class 'str'>
# ExposureTimeAbs
# 	value: 764.0
# 	range: (83.0, 2000000.0)
# 	type:<class 'float'>
# ExposureTimePWL1
# 	value: 15000.0
# 	range: (83.0, 2000000.0)
# 	type:<class 'float'>
# ExposureTimePWL2
# 	value: 15000.0
# 	range: (83.0, 2000000.0)
# 	type:<class 'float'>
# FirmwareVerBuild
# 	value: 18391
# 	range: (0, 4294967295)
# 	type:<class 'int'>
# FirmwareVerMajor
# 	value: 1
# 	range: (0, 4294967295)
# 	type:<class 'int'>
# FirmwareVerMinor
# 	value: 54
# 	range: (0, 4294967295)
# 	type:<class 'int'>
# GVCPCmdRetries
# 	value: 5
# 	range: (1, 9)
# 	type:<class 'int'>
# GVCPCmdTimeout
# 	value: 250
# 	range: (100, 10000)
# 	type:<class 'int'>
# GVSPAdjustPacketSize
# 	value: Cannot get or set the value of a command feature type, call the command instead.
# 	range: None
# 	type:<class 'int'>
# GVSPBurstSize
# 	value: 1
# 	range: (1, 256)
# 	type:<class 'int'>
# GVSPDriver
# 	value: Socket
# 	range: ['Socket', 'Filter']
# 	type:<class 'str'>
# GVSPFilterVersion
# 	value: N/A
# 	range: None
# 	type:<class 'str'>
# GVSPHostReceiveBufferSize
# 	value: 67108864
# 	range: (65536, 4294967295)
# 	type:<class 'int'>
# GVSPMaxLookBack
# 	value: 30
# 	range: (1, 1024)
# 	type:<class 'int'>
# GVSPMaxRequests
# 	value: 1
# 	range: (0, 512)
# 	type:<class 'int'>
# GVSPMaxWaitSize
# 	value: 100
# 	range: (8, 1024)
# 	type:<class 'int'>
# GVSPMissingSize
# 	value: 256
# 	range: (0, 1024)
# 	type:<class 'int'>
# GVSPPacketSize
# 	value: 1500
# 	range: (500, 9973)
# 	type:<class 'int'>
# GVSPTiltingSize
# 	value: 100
# 	range: (0, 1024)
# 	type:<class 'int'>
# GVSPTimeout
# 	value: 70
# 	range: (0, 5000)
# 	type:<class 'int'>
# Gain
# 	value: 0.0
# 	range: (0.0, 26.0)
# 	type:<class 'float'>
# GainAuto
# 	value: Off
# 	range: ['Off', 'Once', 'Continuous']
# 	type:<class 'str'>
# GainAutoAdjustTol
# 	value: 5
# 	range: (0, 50)
# 	type:<class 'int'>
# GainAutoMax
# 	value: 26.0
# 	range: (0.0, 26.0)
# 	type:<class 'float'>
# GainAutoMin
# 	value: 0.0
# 	range: (0.0, 26.0)
# 	type:<class 'float'>
# GainAutoOutliers
# 	value: 0
# 	range: (0, 1000)
# 	type:<class 'int'>
# GainAutoRate
# 	value: 100
# 	range: (1, 100)
# 	type:<class 'int'>
# GainAutoTarget
# 	value: 50
# 	range: (0, 100)
# 	type:<class 'int'>
# GainSelector
# 	value: All
# 	range: ['All']
# 	type:<class 'str'>
# Gamma
# 	value: 1.0
# 	range: (0.25, 4.0)
# 	type:<class 'float'>
# GevCurrentDefaultGateway
# 	value: 16908298
# 	range: (0, 4294967295)
# 	type:<class 'int'>
# GevCurrentIPAddress
# 	value: 1929510922
# 	range: (0, 4294967295)
# 	type:<class 'int'>
# GevCurrentSubnetMask
# 	value: 16777215
# 	range: (0, 4294967295)
# 	type:<class 'int'>
# GevDeviceMACAddress
# 	value: 65252658307
# 	range: (0, 9223372036854775807)
# 	type:<class 'int'>
# GevHeartbeatInterval
# 	value: 1450
# 	range: (200, 1450)
# 	type:<class 'int'>
# GevHeartbeatTimeout
# 	value: 3000
# 	range: (1350, 100000)
# 	type:<class 'int'>
# GevIPConfigurationMode
# 	value: DHCP
# 	range: ['LLA', 'DHCP', 'Persistent']
# 	type:<class 'str'>
# GevPersistentDefaultGateway
# 	value: 0
# 	range: (0, 4294967295)
# 	type:<class 'int'>
# GevPersistentIPAddress
# 	value: 763100841
# 	range: (0, 4294967295)
# 	type:<class 'int'>
# GevPersistentSubnetMask
# 	value: 65535
# 	range: (0, 4294967295)
# 	type:<class 'int'>
# GevSCPSPacketSize
# 	value: 1500
# 	range: (500, 9973)
# 	type:<class 'int'>
# GevTimestampControlLatch
# 	value: Cannot get or set the value of a command feature type, call the command instead.
# 	range: None
# 	type:<class 'int'>
# GevTimestampControlReset
# 	value: Cannot get or set the value of a command feature type, call the command instead.
# 	range: None
# 	type:<class 'int'>
# GevTimestampTickFrequency
# 	value: 1000000000
# 	range: (0, 4294967295)
# 	type:<class 'int'>
# GevTimestampValue
# 	value: 0
# 	range: (0, 9223372036854775807)
# 	type:<class 'int'>
# Height
# 	value: 20
# 	range: (1, 249)
# 	type:<class 'int'>
# HeightMax
# 	value: 484
# 	range: (0, 4294967295)
# 	type:<class 'int'>
# ImageSize
# 	value: 400
# 	range: (0, 4294967295)
# 	type:<class 'int'>
# LUTAddress
# 	value: 196608
# 	range: (0, 4294967295)
# 	type:<class 'int'>
# LUTBitDepthIn
# 	value: 12
# 	range: (0, 4294967295)
# 	type:<class 'int'>
# LUTBitDepthOut
# 	value: 12
# 	range: (0, 4294967295)
# 	type:<class 'int'>
# LUTEnable
# 	value: False
# 	range: None
# 	type:<class 'bool'>
# LUTIndex
# 	value: 0
# 	range: (0, 4095)
# 	type:<class 'int'>
# LUTLoadAll
# 	value: Cannot get or set the value of a command feature type, call the command instead.
# 	range: None
# 	type:<class 'int'>
# LUTMode
# 	value: Luminance
# 	range: ['Luminance', 'Red', 'Green', 'Blue']
# 	type:<class 'str'>
# LUTSaveAll
# 	value: Cannot get or set the value of a command feature type, call the command instead.
# 	range: None
# 	type:<class 'str'>
# LUTSelector
# 	value: LUT1
# 	range: ['LUT1', 'LUT2', 'LUT3', 'LUT4', 'LUT5']
# 	type:<class 'str'>
# LUTSizeBytes
# 	value: 8192
# 	range: (0, 4294967295)
# 	type:<class 'int'>
# LUTValue
# 	value: 4095
# 	range: (0, 4095)
# 	type:<class 'int'>
# MulticastEnable
# 	value: False
# 	range: None
# 	type:<class 'bool'>
# MulticastIPAddress
# 	value: 823132143
# 	range: (224, 4294967279)
# 	type:<class 'int'>
# NonImagePayloadSize
# 	value: 0
# 	range: (0, 4294967295)
# 	type:<class 'int'>
# OffsetX
# 	value: 330
# 	range: (0, 624)
# 	type:<class 'int'>
# OffsetY
# 	value: 235
# 	range: (0, 464)
# 	type:<class 'int'>
# PayloadSize
# 	value: 400
# 	range: (0, 4294967295)
# 	type:<class 'int'>
# PixelFormat
# 	value: Mono8
# 	range: ['Mono8', 'Mono10', 'Mono12', 'Mono12Packed', 'Mono14', 'BayerGR8', 'BayerRG8', 'BayerGB8', 'BayerBG8', 'BayerBG10', 'BayerGR12', 'BayerRG12', 'BayerGB12', 'BayerGR12Packed', 'BayerRG12Packed', 'BayerGB12Packed', 'RGB8Packed', 'BGR8Packed', 'RGBA8Packed', 'BGRA8Packed', 'RGB10Packed', 'RGB12Packed', 'YUV411Packed', 'YUV422Packed', 'YUV444Packed']
# 	type:<class 'str'>
# RecorderPreEventCount
# 	value: 0
# 	range: (0, 65535)
# 	type:<class 'int'>
# ReverseX
# 	value: False
# 	range: None
# 	type:<class 'bool'>
# ReverseY
# 	value: False
# 	range: None
# 	type:<class 'bool'>
# SensorBits
# 	value: 12
# 	range: (0, 4294967295)
# 	type:<class 'int'>
# SensorHeight
# 	value: 484
# 	range: (0, 4294967295)
# 	type:<class 'int'>
# SensorType
# 	value: Mono
# 	range: ['Mono', 'Bayer']
# 	type:<class 'str'>
# SensorWidth
# 	value: 644
# 	range: (0, 4294967295)
# 	type:<class 'int'>
# StatFrameDelivered
# 	value: 0
# 	range: (0, 4294967295)
# 	type:<class 'int'>
# StatFrameDropped
# 	value: 0
# 	range: (0, 4294967295)
# 	type:<class 'int'>
# StatFrameRate
# 	value: 0.0
# 	range: (0.0, 1.7976931348623157e+308)
# 	type:<class 'float'>
# StatFrameRescued
# 	value: 0
# 	range: (0, 4294967295)
# 	type:<class 'int'>
# StatFrameShoved
# 	value: 0
# 	range: (0, 4294967295)
# 	type:<class 'int'>
# StatFrameUnderrun
# 	value: 0
# 	range: (0, 4294967295)
# 	type:<class 'int'>
# StatLocalRate
# 	value: 0.0
# 	range: (0.0, 1.7976931348623157e+308)
# 	type:<class 'float'>
# StatPacketErrors
# 	value: 0
# 	range: (0, 4294967295)
# 	type:<class 'int'>
# StatPacketMissed
# 	value: 0
# 	range: (0, 4294967295)
# 	type:<class 'int'>
# StatPacketReceived
# 	value: 0
# 	range: (0, 4294967295)
# 	type:<class 'int'>
# StatPacketRequested
# 	value: 0
# 	range: (0, 4294967295)
# 	type:<class 'int'>
# StatPacketResent
# 	value: 0
# 	range: (0, 4294967295)
# 	type:<class 'int'>
# StatPacketUnavailable
# 	value: 0
# 	range: (0, 4294967295)
# 	type:<class 'int'>
# StatTimeElapsed
# 	value: 0.0
# 	range: (0.0, 1.7976931348623157e+308)
# 	type:<class 'float'>
# StreamAnnounceBufferMinimum
# 	value: 1
# 	range: (0, 4294967295)
# 	type:<class 'int'>
# StreamAnnouncedBufferCount
# 	value: 0
# 	range: (0, 9223372036854775807)
# 	type:<class 'int'>
# StreamBufferHandlingMode
# 	value: Default
# 	range: ['Default']
# 	type:<class 'str'>
# StreamBytesPerSecond
# 	value: 115000000
# 	range: (1000000, 124000000)
# 	type:<class 'int'>
# StreamFrameRateConstrain
# 	value: True
# 	range: None
# 	type:<class 'bool'>
# StreamHoldCapacity
# 	value: 32384
# 	range: (0, 4294967295)
# 	type:<class 'int'>
# StreamHoldEnable
# 	value: Off
# 	range: ['Off', 'On']
# 	type:<class 'str'>
# StreamID
# 	value: DEV_000F315C8C83-Stream-000
# 	range: None
# 	type:<class 'str'>
# StreamType
# 	value: GEV
# 	range: ['GEV']
# 	type:<class 'str'>
# StrobeDelay
# 	value: 0
# 	range: (0, 330482984)
# 	type:<class 'int'>
# StrobeDuration
# 	value: 0
# 	range: (0, 330482984)
# 	type:<class 'int'>
# StrobeDurationMode
# 	value: Source
# 	range: ['Source', 'Controlled']
# 	type:<class 'str'>
# StrobeSource
# 	value: FrameTrigger
# 	range: ['AcquisitionTriggerReady', 'FrameTriggerReady', 'FrameTrigger', 'Exposing', 'FrameReadout', 'Acquiring', 'LineIn1', 'LineIn2']
# 	type:<class 'str'>
# SyncInGlitchFilter
# 	value: 0
# 	range: (0, 50000)
# 	type:<class 'int'>
# SyncInLevels
# 	value: 0
# 	range: (0, 4294967295)
# 	type:<class 'int'>
# SyncInSelector
# 	value: SyncIn1
# 	range: ['SyncIn1', 'SyncIn2', 'SyncIn3', 'SyncIn4']
# 	type:<class 'str'>
# SyncOutLevels
# 	value: 0
# 	range: (0, 4294967295)
# 	type:<class 'int'>
# SyncOutPolarity
# 	value: Normal
# 	range: ['Normal', 'Invert']
# 	type:<class 'str'>
# SyncOutSelector
# 	value: SyncOut1
# 	range: ['SyncOut1', 'SyncOut2', 'SyncOut3', 'SyncOut4']
# 	type:<class 'str'>
# SyncOutSource
# 	value: Exposing
# 	range: ['GPO', 'AcquisitionTriggerReady', 'FrameTriggerReady', 'Exposing', 'FrameReadout', 'Imaging', 'Acquiring', 'LineIn1', 'LineIn2', 'Strobe1']
# 	type:<class 'str'>
# ThresholdPWL1
# 	value: 63
# 	range: (0, 63)
# 	type:<class 'int'>
# ThresholdPWL2
# 	value: 63
# 	range: (0, 63)
# 	type:<class 'int'>
# TriggerActivation
# 	value: RisingEdge
# 	range: ['RisingEdge', 'FallingEdge', 'AnyEdge', 'LevelHigh', 'LevelLow']
# 	type:<class 'str'>
# TriggerDelayAbs
# 	value: 0.0
# 	range: (0.0, 330482984.0)
# 	type:<class 'float'>
# TriggerMode
# 	value: On
# 	range: ['Off', 'On']
# 	type:<class 'str'>
# TriggerOverlap
# 	value: Off
# 	range: ['Off', 'ReadOut', 'PreviousFrame']
# 	type:<class 'str'>
# TriggerSelector
# 	value: FrameStart
# 	range: ['FrameStart', 'AcquisitionStart', 'AcquisitionEnd', 'AcquisitionRecord']
# 	type:<class 'str'>
# TriggerSoftware
# 	value: Cannot get or set the value of a command feature type, call the command instead.
# 	range: None
# 	type:<class 'str'>
# TriggerSource
# 	value: Freerun
# 	range: ['Freerun', 'Line1', 'Line2', 'Line3', 'Line4', 'FixedRate', 'Software']
# 	type:<class 'str'>
# UserSetDefaultSelector
# 	value: Default
# 	range: ['Default', 'UserSet1', 'UserSet2', 'UserSet3', 'UserSet4', 'UserSet5']
# 	type:<class 'str'>
# UserSetLoad
# 	value: Cannot get or set the value of a command feature type, call the command instead.
# 	range: None
# 	type:<class 'str'>
# UserSetSave
# 	value: Cannot get or set the value of a command feature type, call the command instead.
# 	range: None
# 	type:<class 'str'>
# UserSetSelector
# 	value: Default
# 	range: ['Default', 'UserSet1', 'UserSet2', 'UserSet3', 'UserSet4', 'UserSet5']
# 	type:<class 'str'>
# Width
# 	value: 20
# 	range: (1, 314)
# 	type:<class 'int'>
# WidthMax
# 	value: 644
# 	range: (0, 4294967295)
# 	type:<class 'int'>

# %% [markdown]
# extend the streaming to also save the reading

# %%
drop=0
total=0
array=[]
ROI_sum=0
time_series=[]

left=325 #min value 0
right=425 #max value 644 for Mako
up=150 #min value 0
down=250 #max value 484 for Mako

# time between images in s
twait = 2

fig1 = plt.figure(figsize=(10,5))
ax1 = fig1.add_subplot(111)
plt.ion()
fig1.show()
fig1.canvas.draw()

fig2 = plt.figure(figsize=(2,2))
ax2 = fig2.add_subplot(111)
plt.ion()
fig2.show()
fig2.canvas.draw()

def cp(f,tag):
    image = f.buffer_data_numpy()
    #image = image[up:down,left:right]
    ROI_sum=np.sum(image)
    array.append(ROI_sum)
    #time_series.append((tag,ROI_sum))
    if len(array)>200:
        array.pop(0)
    ax1.clear()
    ax2.clear()
    ax1.plot(array,'o--b')
    ax2.imshow(image,cmap = 'gray')
    fig1.show()
    fig1.canvas.draw()
    fig2.show()
    fig2.canvas.draw()
    #timestamp = time.time()
    now = datetime.now()
    timestamp = now.strftime("%Y-%m-%d %H:%M:%S")
    data = [timestamp, ROI_sum]
    
    path = Path.home().as_posix()
    full_path = Path(path+'/Dropbox (CoQuMa)/LabNotes/NaKa/'+day[:7]+'/'+day+'/')
        
    try:
        with open(str(full_path)+'\\'+'mako_reading_'+timestamp[:10]+'.csv', 'a',newline='', encoding='UTF8') as f:
            writer = csv.writer(f)
            writer.writerow(data)
    except FileNotFoundError :
        with open(Path.cwd().as_posix()+'\\data\\mako_reading_'+timestamp[:10]+'.csv', 'a',newline='', encoding='UTF8') as f:
            writer = csv.writer(f)
            writer.writerow(data)
    
if __name__ == '__main__':

    with Vimba() as vimba:
        camera = vimba.camera('DEV_000F315C8C83')##   DEV_000F315C8C83      DEV_000F315C57F9      DEV_000F315C1307
        camera.open()
        camera.arm('SingleFrame')
        
        timeout = 200000   # [seconds]
        timeout_start = time.time()
  
        while time.time() < timeout_start + timeout:  # Uncomment this to capture frames for a specific time
        #for i in range(200): # Uncomment this to capture a single frame, more than once if desired
            total+=1
            try:
                frame = camera.acquire_frame(100)
                tag=time.time()-timeout_start
                cp(frame,tag)
                time.sleep(twait)
            except VimbaException as e:
                # rearm camera upon frame timeout
                if e.error_code == VimbaException.ERR_TIMEOUT:
                    drop+=1
                    #print(e)
                    camera.disarm()
                    camera.arm('SingleFrame')
                else:
                    raise

        camera.disarm()
        camera.close()

print(drop,'Frames dropped out of',total,'due to timeout')
# Out:
# <img src="data:image/png;base64,..." width="1000.4999701827774">
# <img src="data:image/png;base64,..." width="199.49999405443685">
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-63c0812b2037> in <module>
#      74                 frame = camera.acquire_frame(100)
#      75                 tag=time.time()-timeout_start
# ---> 76                 cp(frame,tag)
#      77                 time.sleep(twait)
#      78             except VimbaException as e:
#
# <ipython-input-6-63c0812b2037> in cp(f, tag)
#      47
#      48     path = Path.home().as_posix()
# ---> 49     full_path = Path(path+'/Dropbox (CoQuMa)/LabNotes/NaKa/'+day[:7]+'/'+day+'/')
#      50
#      51     try:
#
# NameError: name 'day' is not defined
